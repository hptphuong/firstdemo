# %% [markdown]
# # Data sample for test

# %%
import pandas as pd
import random

# %%
df=pd.read_csv('./fsa_log_visit_sample2.csv')

# %%
df.head(1)
# Out:
#    fb0999eb-16ea-481f-a3d8-0ff13feea4f8  d689beb1-0cee-4fcd-81a7-8fbd4f9637fc  \
# 0  2c7b91f8-0acd-441c-be5a-5d1465f4e33d  b58a281c-0f49-4f64-8e05-41ee93fdcb08
#
#    844163cd-deea-43d7-b6f7-4fdbb023528f  1513468462   Safari  Unnamed: 5  \
# 0  9a824c2e-1560-4006-9776-3e3861113c24  1513468335  Firefox         NaN
#
#    Unnamed: 6        iOS  Unnamed: 8  Unnamed: 9  UTF-8  en-us  PL Poland  \
# 0         NaN  (not set)         NaN         NaN  UTF-8  zh-tw  JP  Japan
#
#   204.177.175.17   Apple Tablet
# 0  133.65.72.118  Android Phone

# %%
df.shape
# Out:
# (347, 15)

# %%
# df.loc[df.shape[0]]=df.loc[0]

# %%
for index, row in df.iterrows():
    if(random.randint(0,1)):
        row['m_date']=row['m_date']-round(random.random()*600)
        row['userid']=''
        df.loc[df.shape[0]]=row

# %%
df.to_csv('./fsa_log_visit_sample_modify.csv',header=None,index=False)

# %%
df.sort_values(by=['m_date'],ascending =False)
# Out:
#                                    userid  \
# 346  f7fa6faa-e492-4a66-9f87-5ea8b9971a3c
# 345  e6561674-22e4-490b-97eb-17325ea60cbf
# 503
# 344  099b61d8-fb7b-4b24-8aa8-147c4fabc5fd
# 343  cd411133-b9b5-44ab-a68a-4a6e03fd72f1
# 502
# 342  2f0e0d50-48d5-4b8b-94d8-c4ebc8f4e103
# 501
# 341  b2d0e41a-7667-4d4f-a004-faf9ce2a787a
# 500
# 340  2eb22890-0c49-4fc6-aca1-b0f220663fea
# 499
# 339  a44e5ace-1306-42fd-bb1e-3f0b13ff7d29
# 338  bf82c61e-4813-4fc0-9042-a37c2bd58ffd
# 498
# 337  6fc6025d-45d2-4b36-b624-fde28825c26d
# 336  77bb2955-b0db-40dc-ac44-e35c7c3c81ab
# 335  c7da4950-34b7-42e2-8a21-9158136b9efa
# 497
# 334  012c3b6c-bbe2-4bac-aab1-83641f4b99e0
# 333  35597973-ad16-454d-9cb7-7aaef6f29eef
# 332  1efbfa35-dcce-48e0-a848-b8d236baafef
# 331  04d765ce-63e5-42be-8364-cfb03880e350
# 330  ef5b2b2a-9eac-4975-a4c1-a9f46eb39ca5
# 496
# 329  0361ea99-224d-4b30-8640-d7594f07c128
# 328  00ae7c6d-daf7-46ba-b420-4143a70f2503
# 327  ad6009cf-a397-442a-9aaf-1d36d7bfa69a
# ...

# %%
df.loc[347]
# Out:
# userid
# fsa                       070a0d08-7c5d-47a1-bc4f-868780c57912
# fsid                      816a7e05-4464-45a8-98b4-acc598e040cb
# m_date                                                     100
# config_browser_name                            Safari (in-app)
# config_browser_version                                     NaN
# config_color_depth                                         NaN
# config_os                                                  NaN
# config_resolution                                          NaN
# config_viewport_size                                       NaN
# location_browser_en                                        NaN
# location_browser_lan                                     en-gb
# location_country_code                                       BO
# location_country_name                                  Bolivia
# location_ipv4                                    68.106.19.199
# Name: 347, dtype: object

# %%
round(random.random()*600)
# Out:
# 216
