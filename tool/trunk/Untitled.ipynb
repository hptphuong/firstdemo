# %% [markdown]
# # Data sample for test

# %%
import pandas as pd
import random

# %%
import os 
os.path.dirname(os.getcwd())
# Out:
# 'C:\\Users\\phuonghpt\\Documents\\webanalytic\\DjangoPractice\\draft_phuonganalytic1-firstdemo\\tool'

# %%
df=pd.read_csv('./origin_fsa_log_visit_201712291449.csv')

# %%
df.head(1)
# Out:
#           fsa  userid        fsid      m_date config_browser  \
# 0  2132129733      -1  1495875512  1514349483        Firefox
#
#    config_browser_name  config_browser_version config_color_depth  \
# 0                  NaN                     1.0             24-bit
#
#    config_device  config_java     ...      location_browser_en  \
# 0  Android Phone          NaN     ...                    UTF-8
#
#   location_browser_lan  location_city_name location_country_code  \
# 0                en-us               Hanoi                    VN
#
#   location_country_name  location_ipv4 location_ipv6 locatio_os  \
# 0               Vietnam  10.88.113.111           NaN        Win
#
#    location_path  referal_xxx
# 0  10.88.113.111          NaN
#
# [1 rows x 23 columns]

# %%
df.shape
# Out:
# (318, 23)

# %%
# df.loc[df.shape[0]]=df.loc[0]
random.randint(1,10)
# Out:
# 3

# %%
for index, row in df.iterrows():
    if(random.randint(-10,20)):
        row['m_date']=row['m_date']-round(random.random()*86400*30)
        row['userid']=-1
        df.loc[df.shape[0]]=row

# %%
df.min(axis=0)
# Out:
# fsa                          1197758143
# userid                               -1
# fsid                         1001793528
# m_date                       1511764353
# config_browser                   Chrome
# config_browser_name                None
# config_browser_version                1
# config_color_depth               24-bit
# config_device             Android Phone
# config_java                           0
# config_resolution             1280x1024
# config_viewport_size           1263x893
# idsite                             None
# location_browser_en               UTF-8
# location_browser_lan              en-us
# location_city_name                Hanoi
# location_country_code                CA
# location_country_name            Canada
# location_ipv4             10.88.113.111
# location_ipv6                      None
# locatio_os                          Win
# location_path             10.88.113.111
# referal_xxx                        None
# dtype: object

# %%
df.to_csv('./modify_fsa_log_visit_201712291449.csv',header=None,index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-38-8ec559b3927f> in <module>()
# ----> 1 df.to_csv('./modify_fsa_log_visit_201712291449.csv',header=None,index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1411                                      doublequote=doublequote,
#    1412                                      escapechar=escapechar, decimal=decimal)
# -> 1413         formatter.save()
#    1414
#    1415         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in save(self)
# ...

# %%
df.sort_values(by=['m_date'],ascending =False)
# Out:
#                                     userid  \
# 0     fb0999eb-16ea-481f-a3d8-0ff13feea4f8
# 1     2c7b91f8-0acd-441c-be5a-5d1465f4e33d
# 1516
# 2     b0b166ed-f76f-4988-97a0-28e316524e6d
# 1517
# 1000                                   NaN
# 2016
# 1001                                   NaN
# 2017
# 6     974bc56c-6b63-4db3-91a8-6dd85b718575
# 4     03cb46e2-483d-4954-997f-e06c455ea62a
# 5     bdf9111b-365d-46a2-bada-1c15d0d29b6a
# 3     d413fcb8-b03f-48f5-ae86-c8f625e50b02
# 1003                                   NaN
# 1002                                   NaN
# 2019
# 2018
# 7     9805e7b1-4923-4db3-82b9-eb0bd0df2f38
# 8     8ffb3950-bb1a-48ef-b529-e7ad570d57e0
# 1518
# 1004                                   NaN
# 9     a1f80c54-d5db-4b4c-aeed-a6352503b61d
# 1519
# 1005                                   NaN
# 2020
# 10    7321bb9f-80a6-46cc-90d3-cfa84beb5f85
# 11    20bc4e99-4486-495d-a039-bdfeff94da20
# 12    fbd4ae81-8f5e-4a63-85b6-54fad5f8a51a
# ...

# %%
df.loc[347]
# Out:
# userid                    e3f7dbe7-2a4c-4cea-88b2-f84b453eb960
# fsa                       9c47d2de-f2c0-459f-aeff-6670fb15da9a
# fsid                      86de6997-0260-48f1-9beb-4ceb75d1daba
# m_date                                              1502322784
# config_browser_name                                    Firefox
# config_browser_version                                     NaN
# config_color_depth                                         NaN
# config_os                                            Macintosh
# config_resolution                                          NaN
# config_viewport_size                                       NaN
# location_browser_en                                      UTF-8
# location_browser_lan                                     en-gb
# location_country_code                                       ZA
# location_country_name                             South Africa
# location_ipv4                                    29.228.80.206
# ...

# %%
df.columns
# Out:
# Index(['fsa', 'userid', 'fsid', 'm_date', 'config_browser',
#        'config_browser_name', 'config_browser_version', 'config_color_depth',
#        'config_device', 'config_java', 'config_resolution',
#        'config_viewport_size', 'idsite', 'location_browser_en',
#        'location_browser_lan', 'location_city_name', 'location_country_code',
#        'location_country_name', 'location_ipv4', 'location_ipv6', 'locatio_os',
#        'location_path', 'referal_xxx'],
#       dtype='object')
